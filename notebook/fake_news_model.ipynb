# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
true = pd.read_csv('../data/True.csv')
fake = pd.read_csv('../data/Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake['label']=0

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news = pd.concat([fake, true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news.drop(['title','subject','date'],axis=1)
# Out:
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 21414  MINSK (Reuters) - In the shadow of disused Sov...      1
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1
#
# [44898 rows x 2 columns]

# %%
news = news.sample(frac=1)

# %%
news.head()
# Out:
#                                                    title  \
# 11408  HILARIOUS! Look Who LIBERAL Middlebury Profess...
# 7783    Another Progressive Democrat Lines Up Behind ...
# 3778    Trump’s Selfishness Is Already KILLING Busine...
# 17359  U.S.-led anti-Islamic State coalition says Ira...
# 23101  Obama Joins Comedy Central Host to Push ‘Laugh...
#
#                                                     text      subject  \
# 11408  Two weeks ago at Middlebury College, Charles M...     politics
# 7783   Probably the most highly coveted endorsement b...         News
# 3778   Donald Trump has his staff working on the logi...         News
# 17359  BAGHDAD (Reuters) - The U.S.-led anti-Islamic ...    worldnews
# 23101  21st Century Wire says President Obama is once...  Middle-east
#
#                     date  label
# 11408       Mar 14, 2017      0
# 7783   February 29, 2016      0
# 3778   November 17, 2016      0
# 17359  October 16, 2017       1
# 23101  December 15, 2016      0

# %%
news.tail()
# Out:
#                                                    title  \
# 13649  JIMMY FALLON Brings On “Little Donald” To Be H...
# 9220   Three teenagers arrested over assaults during ...
# 16451  Taiwan president calls for breakthrough in Chi...
# 15691  Thousands march against coal ahead of climate ...
# 1763   Former Trump adviser Flynn's son being probed ...
#
#                                                     text       subject  \
# 13649  This teen has a pretty good impression of Dona...      politics
# 9220   (Reuters) - Three teenagers were arrested on W...  politicsNews
# 16451  TAIPEI (Reuters) - Taiwan and China need to dr...     worldnews
# 15691  FRANKFURT (Reuters) - Thousands of people took...     worldnews
# 1763   WASHINGTON (Reuters) - The son of U.S. Preside...  politicsNews
#
#                       date  label
# 13649         Jun 23, 2016      0
# 9220         June 9, 2016       1
# 16451    October 26, 2017       1
# 15691    November 4, 2017       1
# 1763   September 13, 2017       1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                              title  \
# 0  11408  HILARIOUS! Look Who LIBERAL Middlebury Profess...
# 1   7783   Another Progressive Democrat Lines Up Behind ...
# 2   3778   Trump’s Selfishness Is Already KILLING Busine...
# 3  17359  U.S.-led anti-Islamic State coalition says Ira...
# 4  23101  Obama Joins Comedy Central Host to Push ‘Laugh...
#
#                                                 text      subject  \
# 0  Two weeks ago at Middlebury College, Charles M...     politics
# 1  Probably the most highly coveted endorsement b...         News
# 2  Donald Trump has his staff working on the logi...         News
# 3  BAGHDAD (Reuters) - The U.S.-led anti-Islamic ...    worldnews
# 4  21st Century Wire says President Obama is once...  Middle-east
#
#                 date  label
# 0       Mar 14, 2017      0
# 1  February 29, 2016      0
# 2  November 17, 2016      0
# 3  October 16, 2017       1
# 4  December 15, 2016      0

# %%
news.drop(['index'],axis=1, inplace=True)

# %%
news.head()
# Out:
#                                                title  \
# 0  HILARIOUS! Look Who LIBERAL Middlebury Profess...
# 1   Another Progressive Democrat Lines Up Behind ...
# 2   Trump’s Selfishness Is Already KILLING Busine...
# 3  U.S.-led anti-Islamic State coalition says Ira...
# 4  Obama Joins Comedy Central Host to Push ‘Laugh...
#
#                                                 text      subject  \
# 0  Two weeks ago at Middlebury College, Charles M...     politics
# 1  Probably the most highly coveted endorsement b...         News
# 2  Donald Trump has his staff working on the logi...         News
# 3  BAGHDAD (Reuters) - The U.S.-led anti-Islamic ...    worldnews
# 4  21st Century Wire says President Obama is once...  Middle-east
#
#                 date  label
# 0       Mar 14, 2017      0
# 1  February 29, 2016      0
# 2  November 17, 2016      0
# 3  October 16, 2017       1
# 4  December 15, 2016      0

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Two weeks ago at Middlebury College, Charles M...      0
# 1  Probably the most highly coveted endorsement b...      0
# 2  Donald Trump has his staff working on the logi...      0
# 3  BAGHDAD (Reuters) - The U.S.-led anti-Islamic ...      1
# 4  21st Century Wire says President Obama is once...      0

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jayaprakash V
# [nltk_data]     K\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def clean_text(text):
    # convert to lowercase
    text = text.lower()
    
    # remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    
    # remove content inside brackets (like (Reuters), (VIDEO))
    text = re.sub(r'\(.*?\)', '', text)
    
    # remove non-alphabet characters (keep only letters)
    text = re.sub(r'[^a-z\s]', '', text)
    
    # remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    # remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]

    # remove html tags
    text = re.sub(r'<.*?>', '', text)

    # remove newline characters
    text = re.sub(r'\n', ' ', text)
    
    return " ".join(words)

# %%
news['text'] = news['text'].apply(clean_text)

# %%
news.head()
# Out:
#                                                 text  label
# 0  two weeks ago middlebury college charles murra...      0
# 1  probably highly coveted endorsement either dem...      0
# 2  donald trump staff working logistics allowing ...      0
# 3  baghdad usled antiislamic state coalition said...      1
# 4  st century wire says president obama appearing...      0

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        two weeks ago middlebury college charles murra...
# 1        probably highly coveted endorsement either dem...
# 2        donald trump staff working logistics allowing ...
# 3        baghdad usled antiislamic state coalition said...
# 4        st century wire says president obama appearing...
#                                ...
# 44893    teen pretty good impression donald trumpjack a...
# 44894    three teenagers arrested wednesday accused thr...
# 44895    taipei taiwan china need drop historical bagga...
# 44896    frankfurt thousands people took streets bonn s...
# 44897    washington son us president donald trumps form...
# Name: text, Length: 44898, dtype: str

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        0
#         ..
# 44893    0
# 44894    1
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)

# %%
xv_train = vectorizer.fit_transform(x_train)
xv_test = vectorizer.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3943776 stored elements and shape (31428, 5000)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1693987 stored elements and shape (13470, 5000)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(xv_test)

# %%
model.score(xv_test, y_test)
# Out:
# 0.9805493689680772

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7035
#            1       0.98      0.98      0.98      6435
#
#     accuracy                           0.98     13470
#    macro avg       0.98      0.98      0.98     13470
# weighted avg       0.98      0.98      0.98     13470

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(xv_train, y_train)

# %%
dt_pred = dt_model.predict(xv_test)
dt_score = dt_model.score(xv_test, y_test)
print(f'Decision Tree Accuracy: {dt_score:.4f}')

# %%
print('Decision Tree Classification Report:')
print(classification_report(y_test, dt_pred))

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(xv_train, y_train)

# %%
rf_pred = rf_model.predict(xv_test)
rf_score = rf_model.score(xv_test, y_test)
print(f'Random Forest Accuracy: {rf_score:.4f}')

# %%
print('Random Forest Classification Report:')
print(classification_report(y_test, rf_pred))

# %% [markdown]
# ## Model Comparison

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = ['Logistic Regression', 'Decision Tree', 'Random Forest']
preds  = [y_pred, dt_pred, rf_pred]

results = []
for name, pred in zip(models, preds):
    results.append({
        'Model':     name,
        'Accuracy':  accuracy_score(y_test, pred),
        'Precision': precision_score(y_test, pred),
        'Recall':    recall_score(y_test, pred),
        'F1 Score':  f1_score(y_test, pred),
    })

comparison_df = pd.DataFrame(results)
comparison_df = comparison_df.set_index('Model')
print(comparison_df.round(4))

# %%
# Bar chart comparison
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
x = range(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

colors = ['#4C72B0', '#DD8452', '#55A868']
for i, (model_name, row) in enumerate(comparison_df.iterrows()):
    vals = [row[m] for m in metrics]
    bars = ax.bar([xi + i*width for xi in x], vals, width, label=model_name, color=colors[i])
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.002,
                f'{val:.3f}', ha='center', va='bottom', fontsize=8)

ax.set_xlabel('Metric')
ax.set_ylabel('Score')
ax.set_title('Model Comparison — Fake News Detection')
ax.set_xticks([xi + width for xi in x])
ax.set_xticklabels(metrics)
ax.set_ylim(0.85, 1.02)
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Confusion matrices side by side
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, name, pred in zip(axes, models, preds):
    cm = confusion_matrix(y_test, pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Fake', 'True'])
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    ax.set_title(name)

plt.suptitle('Confusion Matrices', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
