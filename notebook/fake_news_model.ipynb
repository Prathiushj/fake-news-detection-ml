# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('../data/True.csv')
fake = pd.read_csv('../data/Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
fake['label']=0

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news = pd.concat([fake, true],axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news.drop(['title','subject','date'],axis=1)
# Out:
#                                                     text  label
# 0      Donald Trump just couldn t wish all Americans ...      0
# 1      House Intelligence Committee Chairman Devin Nu...      0
# 2      On Friday, it was revealed that former Milwauk...      0
# 3      On Christmas day, Donald Trump announced that ...      0
# 4      Pope Francis used his annual Christmas Day mes...      0
# ...                                                  ...    ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...      1
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...      1
# 21414  MINSK (Reuters) - In the shadow of disused Sov...      1
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...      1
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...      1
#
# [44898 rows x 2 columns]

# %%
news = news.sample(frac=1)

# %%
news.head()
# Out:
#                                                    title  \
# 633    U.S. small business community pushes Congress ...
# 9755   HOW OBAMA’S BROKEN U.S. Deportation Process an...
# 1767   House Speaker Ryan leaves door open on taxes, ...
# 11249  ROB SCHNEIDER Nails The Russia Conspiracy Theo...
# 20185  VIDEO SHOWS SCARY TRUTH About What Decades Of ...
#
#                                                     text       subject  \
# 633    WASHINGTON (Reuters) - The U.S. small business...  politicsNews
# 9755   U.S. Immigration and Customs Enforcement said ...      politics
# 1767   WASHINGTON (Reuters) - U.S. House Speaker Paul...  politicsNews
# 11249                                                         politics
# 20185  We live near the city of Detroit, and anyone c...     left-news
#
#                       date  label
# 633     November 15, 2017       1
# 9755           Oct 3, 2017      0
# 1767   September 13, 2017       1
# 11249         Mar 30, 2017      0
# 20185          Aug 1, 2016      0

# %%
news.tail()
# Out:
#                                                    title  \
# 253          Congress averts government shutdown for now
# 7990   Washington Post calls for Maine governor to re...
# 14816  German parties want lobbyist registry, may man...
# 3813   Senators pledge aggressive Russia probe after ...
# 2903   UK PM May to hold bilateral meeting with Trump...
#
#                                                     text       subject  \
# 253    WASHINGTON (Reuters) - The U.S. Congress moved...  politicsNews
# 7990   BOSTON (Reuters) - The Washington Post on Wedn...  politicsNews
# 14816  BERLIN (Reuters) - German parties exploring a ...     worldnews
# 3813   WASHINGTON (Reuters) - The leaders of the Sena...  politicsNews
# 2903   LONDON (Reuters) - British Prime Minister Ther...  politicsNews
#
#                       date  label
# 253      December 7, 2017       1
# 7990   September 28, 2016       1
# 14816   November 14, 2017       1
# 3813         May 11, 2017       1
# 2903         July 5, 2017       1

# %%
news.reset_index(inplace=True)

# %%
news.head()
# Out:
#    index                                              title  \
# 0    633  U.S. small business community pushes Congress ...
# 1   9755  HOW OBAMA’S BROKEN U.S. Deportation Process an...
# 2   1767  House Speaker Ryan leaves door open on taxes, ...
# 3  11249  ROB SCHNEIDER Nails The Russia Conspiracy Theo...
# 4  20185  VIDEO SHOWS SCARY TRUTH About What Decades Of ...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The U.S. small business...  politicsNews
# 1  U.S. Immigration and Customs Enforcement said ...      politics
# 2  WASHINGTON (Reuters) - U.S. House Speaker Paul...  politicsNews
# 3                                                         politics
# 4  We live near the city of Detroit, and anyone c...     left-news
#
#                   date  label
# 0   November 15, 2017       1
# 1          Oct 3, 2017      0
# 2  September 13, 2017       1
# 3         Mar 30, 2017      0
# 4          Aug 1, 2016      0

# %%
news.drop(['index'],axis=1, inplace=True)

# %%
news.head()
# Out:
#                                                title  \
# 0  U.S. small business community pushes Congress ...
# 1  HOW OBAMA’S BROKEN U.S. Deportation Process an...
# 2  House Speaker Ryan leaves door open on taxes, ...
# 3  ROB SCHNEIDER Nails The Russia Conspiracy Theo...
# 4  VIDEO SHOWS SCARY TRUTH About What Decades Of ...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The U.S. small business...  politicsNews
# 1  U.S. Immigration and Customs Enforcement said ...      politics
# 2  WASHINGTON (Reuters) - U.S. House Speaker Paul...  politicsNews
# 3                                                         politics
# 4  We live near the city of Detroit, and anyone c...     left-news
#
#                   date  label
# 0   November 15, 2017       1
# 1          Oct 3, 2017      0
# 2  September 13, 2017       1
# 3         Mar 30, 2017      0
# 4          Aug 1, 2016      0

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  WASHINGTON (Reuters) - The U.S. small business...      1
# 1  U.S. Immigration and Customs Enforcement said ...      0
# 2  WASHINGTON (Reuters) - U.S. House Speaker Paul...      1
# 3                                                         0
# 4  We live near the city of Detroit, and anyone c...      0

# %%
import re
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jayaprakash V
# [nltk_data]     K\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
def clean_text(text):
    # convert to lowercase
    text = text.lower()
    
    # remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text)
    
    # remove content inside brackets (like (Reuters), (VIDEO))
    text = re.sub(r'\(.*?\)', '', text)
    
    # remove non-alphabet characters (keep only letters)
    text = re.sub(r'[^a-z\s]', '', text)
    
    # remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    # remove stopwords
    words = text.split()
    words = [word for word in words if word not in stop_words]

    # remove html tags
    text = re.sub(r'<.*?>', '', text)

    # remove newline characters
    text = re.sub(r'\n', ' ', text)
    
    return " ".join(words)

# %%
news['text'] = news['text'].apply(clean_text)

# %%
news.head()
# Out:
#                                                 text  label
# 0  washington us small business community tuesday...      1
# 1  us immigration customs enforcement said tuesda...      0
# 2  washington us house speaker paul ryan wednesda...      1
# 3                                                         0
# 4  live near city detroit anyone could literally ...      0

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        washington us small business community tuesday...
# 1        us immigration customs enforcement said tuesda...
# 2        washington us house speaker paul ryan wednesda...
# 3
# 4        live near city detroit anyone could literally ...
#                                ...
# 44893    washington us congress moved rapidly thursday ...
# 44894    boston washington post wednesday called maine ...
# 44895    berlin german parties exploring coalition gove...
# 44896    washington leaders senate intelligence committ...
# 44897    london british prime minister theresa may hold...
# Name: text, Length: 44898, dtype: str

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 44893    1
# 44894    1
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)

# %%
xv_train = vectorizer.fit_transform(x_train)
xv_test = vectorizer.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 3938991 stored elements and shape (31428, 5000)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1698397 stored elements and shape (13470, 5000)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(xv_test)

# %%
model.score(xv_test, y_test)
# Out:
# 0.9805493689680772

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      7020
#            1       0.98      0.98      0.98      6450
#
#     accuracy                           0.98     13470
#    macro avg       0.98      0.98      0.98     13470
# weighted avg       0.98      0.98      0.98     13470

# %% [markdown]
# ## Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_pred = dt_model.predict(xv_test)
dt_score = dt_model.score(xv_test, y_test)
print(f'Decision Tree Accuracy: {dt_score:.4f}')
# Out:
# Decision Tree Accuracy: 0.9414

# %%
print('Decision Tree Classification Report:')
print(classification_report(y_test, dt_pred))
# Out:
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      7020
#            1       0.95      0.93      0.94      6450
#
#     accuracy                           0.94     13470
#    macro avg       0.94      0.94      0.94     13470
# weighted avg       0.94      0.94      0.94     13470

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf_model.predict(xv_test)
rf_score = rf_model.score(xv_test, y_test)
print(f'Random Forest Accuracy: {rf_score:.4f}')
# Out:
# Random Forest Accuracy: 0.9855

# %%
print('Random Forest Classification Report:')
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      7020
#            1       0.98      0.99      0.98      6450
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %% [markdown]
# ## Model Comparison

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = ['Logistic Regression', 'Decision Tree', 'Random Forest']
preds  = [y_pred, dt_pred, rf_pred]

results = []
for name, pred in zip(models, preds):
    results.append({
        'Model':     name,
        'Accuracy':  accuracy_score(y_test, pred),
        'Precision': precision_score(y_test, pred),
        'Recall':    recall_score(y_test, pred),
        'F1 Score':  f1_score(y_test, pred),
    })

comparison_df = pd.DataFrame(results)
comparison_df = comparison_df.set_index('Model')
print(comparison_df.round(4))
# Out:
# Matplotlib is building the font cache; this may take a moment.
#                      Accuracy  Precision  Recall  F1 Score
# Model
# Logistic Regression    0.9805     0.9772  0.9823    0.9797
# Decision Tree          0.9414     0.9491  0.9273    0.9380
# Random Forest          0.9855     0.9827  0.9871    0.9849

# %%
# Bar chart comparison
metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
x = range(len(metrics))
width = 0.25

fig, ax = plt.subplots(figsize=(10, 6))

colors = ['#4C72B0', '#DD8452', '#55A868']
for i, (model_name, row) in enumerate(comparison_df.iterrows()):
    vals = [row[m] for m in metrics]
    bars = ax.bar([xi + i*width for xi in x], vals, width, label=model_name, color=colors[i])
    for bar, val in zip(bars, vals):
        ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.002,
                f'{val:.3f}', ha='center', va='bottom', fontsize=8)

ax.set_xlabel('Metric')
ax.set_ylabel('Score')
ax.set_title('Model Comparison — Fake News Detection')
ax.set_xticks([xi + width for xi in x])
ax.set_xticklabels(metrics)
ax.set_ylim(0.85, 1.02)
ax.legend()
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Confusion matrices side by side
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for ax, name, pred in zip(axes, models, preds):
    cm = confusion_matrix(y_test, pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Fake', 'True'])
    disp.plot(ax=ax, colorbar=False, cmap='Blues')
    ax.set_title(name)

plt.suptitle('Confusion Matrices', fontsize=13, y=1.02)
plt.tight_layout()
plt.show()
